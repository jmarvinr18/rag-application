# %% [markdown]
# ### Models Integration with OpenAI, Google Gemini and Groq

# %%
import os
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from langchain.chat_models import init_chat_model

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
# os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
model = ChatOpenAI(model="gpt-4o")
print(model)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001F22D314690> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001F22D314B90> root_client=<openai.OpenAI object at 0x000001F22D3142D0> root_async_client=<openai.AsyncOpenAI object at 0x000001F22D314910> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
model.invoke("Write me a 50 words paragrapth on Master Chef.")
# Out:
# AIMessage(content='MasterChef is a renowned cooking competition that captivates audiences worldwide with its blend of culinary artistry and intense rivalry. Contestants, ranging from amateur cooks to seasoned chefs, showcase their skills under pressure, crafting exquisite dishes. Guided by acclaimed judges, they undergo a transformative journey, highlighting resilience, creativity, and a deep passion for gastronomy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 20, 'total_tokens': 87, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D7a9yMRRx1x2NYe8Tn4NxOn8balAA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c45ec-b168-7ab2-b53a-447b1dc4144e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 67, 'total_tokens': 87, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### Streaming
#
# Most models can stream their output content while it being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use loop to process each chunk in real-time:

# %%
for chunk in model.stream("Write me a 300 words paragraph on Master Chef."):
    print(chunk.text, end="", flush=True)
# Out:
# MasterChef is a globally renowned competitive cooking reality television show that has captivated audiences with its intense culinary challenges and dramatic flair since its inception. Originating in the UK in 1990, the franchise has expanded to various countries, each adding its own cultural twist to the series while maintaining the core elements that make it so compelling. The show typically features amateur chefs who possess a passion for cooking and aspire to transform their hobby into a professional career. Contestants are tasked with a series of challenges, from mystery box challenges where their creativity is tested with a limited set of ingredients to pressure tests that measure their technical skills and ability to perform under time constraints. Throughout the series, they are judged by a panel of esteemed chefs and culinary experts who evaluate their dishes based on taste, presentation, and innovation.
#
# MasterChef's allure lies in its ability to showcase not only the culinary expertise of its contestants but also their personal growth and resilience. Viewers are drawn into the contestants' journeys, witnessing moments of triumph and setback, which makes for emotional and compelling storytelling. In addition to its entertainment value, the show has a significant impact on food culture by introducing audiences to diverse cuisines and cooking techniques. It places a spotlight on the importance of quality ingredients and fosters a broader appreciation of food as an art form.
#
# Moreover, MasterChef has successfully launched the careers of many talented chefs who have gone on to publish cookbooks, open restaurants, and become influential figures in the culinary world. By providing a platform that combines competition, mentorship, and opportunity, MasterChef continues to inspire both aspiring chefs and food enthusiasts alike, ensuring its enduring popularity and legacy in the realm of cooking entertainment.

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="", flush=True)
# Out:
# Parrots are known for their vibrant and colorful feathers, and there are several reasons for this striking feature:
#
# 1. **Camouflage**: Although it might seem counterintuitive, the bright colors can help parrots blend into the colorful environments of their native habitats, such as rainforests where flowers, fruits, and foliage are equally vivid.
#
# 2. **Species and Mate Recognition**: The diverse feather colors help parrots identify members of their own species, which is essential for mating and social interactions. Bright and distinct colors can attract potential mates and signal a healthy and genetically fit individual.
#
# 3. **Social Signaling**: In many parrot species, coloration can also serve as a social signal within flocks. Different colors or patterns can indicate age, sex, or hierarchy status, facilitating social structure and communication within the group.
#
# 4. **Predator Deterrence**: Bright coloring may confuse or startle predators, providing parrots with a slight advantage when trying to evade capture.
#
# 5. **Genetic Factors**: The production of colorful pigments is a result of genetic factors and diet. Parrots synthesize pigments and also rely on food sources to maintain their vibrant colors. The brilliance of their feathers can indicate good health and access to nutritious resources.
#
# Overall, the colorful feathers of parrots have evolved to provide multiple advantages for survival and reproduction in their natural environments.

# %% [markdown]
# ### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers",
    "How do airplanes fly",
    "What is quantum computing"],
    config={
        "max_concurrency": 5
    })

responses
# Out:
# [AIMessage(content='Parrots have colorful feathers for several reasons, primarily related to communication, mating, and survival.\n\n1. **Mating and Attraction**: Brightly colored feathers play a significant role in courtship and mating. In many parrot species, vibrant colors indicate health and genetic fitness, attracting potential mates. This is an example of sexual selection, where certain traits evolve because they are attractive to the opposite sex.\n\n2. **Communication**: Colorful plumage can also facilitate communication between parrots. Different colors and patterns may help individuals identify each other and establish social bonds within the flock. It can also serve to communicate status and hierarchy within the group.\n\n3. **Camouflage and Protection**: For some species, vibrant feathers can serve as camouflage within their natural habitats. In environments such as tropical rainforests, the dappled sunlight and diverse plant life create a complex visual landscape where bright colors can help parrots blend in, making it harder for predators to spot them.\n\n4. **Species and Individual Recognition**: The wide variety of colors and patterns helps species and individual parrots recognize each other. This can be crucial in complex, multi-species environments where different parrot species coexist.\n\n5. **Thermoregulation and UV Protection**: While less common, some theories suggest that certain feather pigments might help with aspects like thermoregulation or protection from ultraviolet radiation.\n\nOverall, the colorful feathers of parrots serve multiple purposes, all of which contribute to their survival and reproductive success in their natural habitats.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 304, 'prompt_tokens': 14, 'total_tokens': 318, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D7u5eKn12TwoPbPULEIx2etOCpk3S', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4a7d-b160-7742-bf79-0474eb200dc5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 304, 'total_tokens': 318, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content="Airplanes fly through the principles of aerodynamics, which involve four primary forces: lift, weight, thrust, and drag.\n\n1. **Lift**: This force counteracts the weight of the airplane and is generated by the wings. The shape of the wings, known as an airfoil, is designed to create a pressure difference between the upper and lower surfaces of the wing as air flows over it. The air moves faster over the top, creating lower pressure and resulting in an upward lift force.\n\n2. **Weight**: This force is due to gravity and pulls the airplane downward. For an airplane to maintain flight, the lift must be equal to or greater than the weight.\n\n3. **Thrust**: Produced by the aircraft's engines, thrust propels the airplane forward. The engines accelerate air backward, and due to Newton's third law of motion, an equal and opposite reaction pushes the airplane forward.\n\n4. **Drag**: This is the resistance force that acts opposite to the direction of motion. It is caused by air friction and pressure differences. Minimizing drag while maximizing thrust is essential for efficient flight.\n\nThe pilot controls the airplane using various control surfaces—ailerons, elevators, and rudders—to maneuver and stabilize the aircraft. By balancing these forces and adjusting the control surfaces, an airplane can climb, descend, turn, and perform other maneuvers.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 277, 'prompt_tokens': 11, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D7u5ecyMAz9jYdAv2miOaJFgImdh3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4a7d-b169-7120-9ff0-e7b4f2a8999d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 277, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content="Quantum computing is a type of computation that leverages the principles of quantum mechanics, the fundamental theory in physics that describes nature at the smallest scales, such as that of subatomic particles. Unlike classical computers, which use bits as the basic unit of information (representing a 0 or a 1), quantum computers use quantum bits or qubits.\n\n### Key Concepts of Quantum Computing:\n\n1. **Superposition**: Qubits can exist in a combination of both 0 and 1 states simultaneously. This allows quantum computers to process a vast number of possibilities all at once, unlike classical computers that have to process each possibility sequentially.\n\n2. **Entanglement**: Qubits can be entangled, meaning the state of one qubit is directly related to the state of another, no matter the distance between them. This property permits the qubits to be correlated in ways that can enhance computational power and speed.\n\n3. **Quantum Interference**: Quantum algorithms use interference patterns to amplify the correct answers and cancel out the wrong ones, paving the way to arrive at a solution more efficiently than classical algorithms.\n\n### Potential and Challenges:\n\n- **Computational Power**: Quantum computers have the potential to solve problems that are currently intractable for classical computers. For example, they could be used to factorize large numbers (a task involved in encryption), simulate quantum physics problems, or optimize complex systems.\n  \n- **Current Stage**: As of now, quantum computing is still in experimental stages. Companies and research institutions are actively developing different architectures, such as superconducting qubits, trapped ions, and topological qubits.\n\n- **Quantum Supremacy**: This term refers to the point at which a quantum computer can perform a calculation that is infeasible for a classical computer in any reasonable amount of time. In 2019, Google's quantum computer, Sycamore, reportedly achieved this milestone in a specific, narrow task.\n\n- **Error Rates and Qubit Scalability**: Quantum computers are more prone to errors due to decoherence and noise, and building a large-scale, reliable quantum computer is a significant challenge. Scientists are working on error correction techniques and ways to increase the number of qubits in a quantum system.\n\nIn summary, quantum computing promises to revolutionize fields requiring complex computation, although practical, scalable, universally applicable quantum computers may still be years away.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 481, 'prompt_tokens': 11, 'total_tokens': 492, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D7u5ee3mtFxWSxy6R6P7AUStQNGsc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4a7d-b187-7dc1-b823-2ce37321f952-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 481, 'total_tokens': 492, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
